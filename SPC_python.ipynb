# %%
import numpy as np 
import math
import pandas as pd 
from pandas import DataFrame, read_csv
import statsmodels.api as sm
import xlsxwriter
from scipy.stats import norm
import matplotlib.pyplot as plt
import source as ss
import scipy
from lifelines import KaplanMeierFitter
from sklearn.datasets import load_iris
import pandas as pd
import scipy.stats as scs
import seaborn as sns
import statistics as stat 


# %load_ext autoreload
# %autoreload 2
# Out:
# c:\Users\byeongiae.chun\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# c:\Users\byeongiae.chun\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# ## Set up the inputs

# %%
batchNo = '4988263'
SideID = [1,2]
numOfTest = 10
LimitsTarget ={'Weight':[220,236,204],
               'Hardness':[12.0,15.0,8.0],
               'Thickness':[3.90,4.10,3.71]}

# %% [markdown]
# ## Data Exporting from one excel to python to another excel

# %%
[data1,data2,time] = ss.Exporter(batchNo,SideID,numOfTest)

# %% [markdown]
# ## Normal distribution Test

# %%
ss.normal_dist(batchNo,SideID,numOfTest)

# %% [markdown]
# ## Empirical CDF plots

# %%
ss.ECDFgen(batchNo,SideID,numOfTest)

# %% [markdown]
# ## Individual Chart

# %%
ss.IChart(batchNo,SideID,numOfTest,LimitsTarget)

# %% [markdown]
# ## Averaged Chart

# %%
ss.AChart(batchNo,SideID,numOfTest,LimitsTarget)

# %% [markdown]
# ## I-MR Chart

# %%
ss.IMChart(batchNo,SideID,numOfTest)
# Out:
# All points within control limits.
# Unit 101 out of control limits!
# Unit 8 out of cotrol limits!
# Unit 104 out of control limits!
# Unit 136 out of control limits!
# Unit 18 out of cotrol limits!
# Unit 201 out of control limits!
# Unit 214 out of control limits!
# Unit 276 out of control limits!
# All points within control limits.
# All points within control limits.
# All points within control limits.
# All points within control limits.
# All points within control limits.
# All points within control limits.
# Unit 44 out of cotrol limits!
# Unit 44 out of control limits!
# Unit 45 out of control limits!
# Unit 104 out of cotrol limits!
# Unit 104 out of control limits!
# Unit 5 out of cotrol limits!
# Unit 84 out of cotrol limits!
# Unit 214 out of cotrol limits!
# Unit 84 out of control limits!
# Unit 85 out of control limits!

# %% [markdown]
# ## Data Summary

# %%
ss.DSCA(batchNo,SideID,numOfTest,LimitsTarget)
